# %%
import cv2
from ultralytics import YOLO
import torch

# %%
metrics_files = {
    'YOLO-n': './runs/detect/train6',
    'YOLO-l': './runs/detect/train15',
    'YOLO-x': './runs/detect/train_yolo_x',
    'RT-DETR-l': '/runs/detect/train14',
    'RT-DETR-x': '/runs/detect/train_rtdetr_x',
}

# %%
yolo11n_model = YOLO(f'./{metrics_files["YOLO-n"]}/weights/best.pt')

# %%
def generate_inference_video(model, input_path, output_path):
    # Input and output video paths
    input_video_path = input_path
    output_video_path = output_path

    # Open the video file
    cap = cv2.VideoCapture(input_video_path)

    # Get video properties
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for output video

    # Create a VideoWriter object
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

    # Process the video frame-by-frame
    frame_count = 0
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            print("End of video or failed to read frame.")
            break

        # Resize the frame to 384x384 as required by your model
        resized_frame = cv2.resize(frame, (384, 384))

        # Run YOLO model on the resized frame
        results = model.predict(
            resized_frame,
            imgsz=384,
            device='cuda' if torch.cuda.is_available() else 'cpu')

        # Extract predictions (bounding boxes, labels, etc.)
        boxes = results[0].boxes.xyxy  # Bounding box coordinates in 384x384
        confidences = results[0].boxes.conf  # Confidence scores
        class_ids = results[0].boxes.cls  # Class IDs

        # Map bounding boxes back to the original frame dimensions
        scale_x = width / 384
        scale_y = height / 384
        mapped_boxes = []
        for box in boxes:
            x1, y1, x2, y2 = box.tolist()
            x1 *= scale_x
            y1 *= scale_y
            x2 *= scale_x
            y2 *= scale_y
            mapped_boxes.append((int(x1), int(y1), int(x2), int(y2)))

        # Draw bounding boxes on the original frame
        for (x1, y1, x2, y2), conf, cls in zip(mapped_boxes, confidences,
                                               class_ids):
            label = f"{model.names[int(cls)]} {conf:.2f}"
            color = (0, 255, 0)  # Green color for bounding boxes
            # Draw bounding box with increased thickness
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, thickness=3)
            # Add text with larger font scale and thickness
            cv2.putText(frame,
                        label, (x1, max(0, y1 - 10)),
                        cv2.FONT_HERSHEY_SIMPLEX,
                        fontScale=1.4,
                        color=color,
                        thickness=3)

        # Write the annotated frame to the output video
        out.write(frame)
        frame_count += 1
        print(f"Processed frame {frame_count}")

    # Release resources
    cap.release()
    out.release()
    print(f"Processed video saved to: {output_video_path}")

# %%
generate_inference_video(yolo11n_model, 'test_inference.mp4',
                         'output_video.mp4')
# Out:
# 0: 384x384 (no detections), 7.6ms
# Speed: 9.6ms preprocess, 7.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 1
#
# 0: 384x384 (no detections), 7.2ms
# Speed: 0.7ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 2
#
# 0: 384x384 1 Letter: Y, 7.1ms
# Speed: 0.7ms preprocess, 7.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 3
#
# 0: 384x384 1 Letter: L, 1 Letter: Y, 7.1ms
# Speed: 0.6ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 4
#
# 0: 384x384 1 Letter: Y, 7.2ms
# Speed: 0.7ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 5
#
# 0: 384x384 1 Letter: Y, 7.1ms
# Speed: 0.7ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 6
#
# 0: 384x384 1 Letter: Y, 7.1ms
# Speed: 0.6ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 7
#
# 0: 384x384 1 Letter: Y, 7.2ms
# Speed: 0.6ms preprocess, 7.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 8
#
# 0: 384x384 1 Letter: Y, 7.3ms
# Speed: 0.6ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 9
#
# 0: 384x384 (no detections), 7.2ms
# Speed: 0.7ms preprocess, 7.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 10
#
# 0: 384x384 (no detections), 7.2ms
# Speed: 0.8ms preprocess, 7.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 11
#
# 0: 384x384 1 Letter: Y, 6.7ms
# Speed: 0.7ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 12
#
# 0: 384x384 1 Letter: L, 1 Letter: Y, 7.3ms
# Speed: 0.7ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 13
#
# 0: 384x384 1 Letter: L, 1 Letter: Y, 7.2ms
# Speed: 0.7ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 14
#
# 0: 384x384 1 Letter: L, 1 Letter: Y, 7.2ms
# Speed: 0.7ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 15
#
# 0: 384x384 1 Letter: L, 1 Letter: Y, 7.0ms
# Speed: 0.7ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 16
#
# 0: 384x384 1 Letter: L, 1 Letter: Y, 7.2ms
# Speed: 0.7ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 17
#
# 0: 384x384 1 Letter: L, 1 Letter: Y, 7.0ms
# Speed: 0.7ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 18
#
# 0: 384x384 1 Letter: L, 1 Letter: Y, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 19
#
# 0: 384x384 1 Letter: L, 1 Letter: Y, 6.3ms
# Speed: 0.6ms preprocess, 6.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 20
#
# 0: 384x384 1 Letter: L, 1 Letter: Y, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 21
#
# 0: 384x384 1 Letter: L, 1 Letter: Y, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 22
#
# 0: 384x384 1 Letter: L, 1 Letter: Y, 6.6ms
# Speed: 0.7ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 23
#
# 0: 384x384 1 Letter: L, 1 Letter: Y, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 24
#
# 0: 384x384 1 Letter: Y, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 25
#
# 0: 384x384 1 Letter: Y, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 26
#
# 0: 384x384 1 Letter: Y, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 27
#
# 0: 384x384 1 Letter: Y, 6.6ms
# Speed: 0.7ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 28
#
# 0: 384x384 1 Letter: Y, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 29
#
# 0: 384x384 1 Letter: Y, 6.4ms
# Speed: 0.7ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 30
#
# 0: 384x384 1 Letter: Y, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 31
#
# 0: 384x384 1 Letter: Y, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 32
#
# 0: 384x384 1 Letter: Y, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 33
#
# 0: 384x384 1 Letter: Y, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 34
#
# 0: 384x384 1 Letter: Y, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 35
#
# 0: 384x384 1 Letter: Y, 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 36
#
# 0: 384x384 1 Letter: Y, 6.4ms
# Speed: 0.7ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 37
#
# 0: 384x384 1 Letter: Y, 7.1ms
# Speed: 0.8ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 38
#
# 0: 384x384 1 Letter: Y, 6.4ms
# Speed: 0.5ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 39
#
# 0: 384x384 1 Letter: Y, 6.5ms
# Speed: 0.8ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 40
#
# 0: 384x384 1 Letter: Y, 6.7ms
# Speed: 0.7ms preprocess, 6.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 41
#
# 0: 384x384 1 Letter: Y, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 42
#
# 0: 384x384 1 Letter: Y, 6.4ms
# Speed: 0.7ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 43
#
# 0: 384x384 1 Letter: Y, 6.5ms
# Speed: 0.5ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 44
#
# 0: 384x384 1 Letter: L, 1 Letter: Y, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 45
#
# 0: 384x384 1 Letter: Y, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 46
#
# 0: 384x384 1 Letter: Y, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 47
#
# 0: 384x384 1 Letter: Y, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 48
#
# 0: 384x384 1 Letter: Y, 6.4ms
# Speed: 0.7ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 49
#
# 0: 384x384 1 Letter: Y, 6.4ms
# Speed: 0.5ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 50
#
# 0: 384x384 1 Letter: Y, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 51
#
# 0: 384x384 1 Letter: Y, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 52
#
# 0: 384x384 1 Letter: Y, 6.5ms
# Speed: 0.5ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 53
#
# 0: 384x384 1 Letter: Y, 6.4ms
# Speed: 0.8ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 54
#
# 0: 384x384 1 Letter: Y, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 55
#
# 0: 384x384 1 Letter: Y, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 56
#
# 0: 384x384 1 Letter: Y, 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 57
#
# 0: 384x384 1 Letter: Y, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 58
#
# 0: 384x384 1 Letter: Y, 6.6ms
# Speed: 0.7ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 59
#
# 0: 384x384 (no detections), 7.3ms
# Speed: 0.7ms preprocess, 7.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 60
#
# 0: 384x384 (no detections), 7.0ms
# Speed: 0.8ms preprocess, 7.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 61
#
# 0: 384x384 1 Letter: Y, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 62
#
# 0: 384x384 1 Letter: Y, 6.4ms
# Speed: 0.8ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 63
#
# 0: 384x384 1 Letter: Y, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 64
#
# 0: 384x384 1 Letter: Y, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 65
#
# 0: 384x384 1 Letter: Y, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 66
#
# 0: 384x384 1 Letter: Y, 6.8ms
# Speed: 0.6ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 67
#
# 0: 384x384 1 Letter: Y, 6.7ms
# Speed: 0.7ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 68
#
# 0: 384x384 (no detections), 6.5ms
# Speed: 0.5ms preprocess, 6.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 69
#
# 0: 384x384 1 Letter: Y, 6.8ms
# Speed: 0.6ms preprocess, 6.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 70
#
# 0: 384x384 1 Letter: Y, 7.4ms
# Speed: 0.6ms preprocess, 7.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 71
#
# 0: 384x384 1 Letter: Y, 8.9ms
# Speed: 0.6ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 72
#
# 0: 384x384 1 Letter: G, 8.1ms
# Speed: 0.8ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 73
#
# 0: 384x384 1 Letter: G, 7.4ms
# Speed: 0.6ms preprocess, 7.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 74
#
# 0: 384x384 1 Letter: G, 8.6ms
# Speed: 0.7ms preprocess, 8.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 75
#
# 0: 384x384 1 Letter: E, 7.8ms
# Speed: 0.6ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 76
#
# 0: 384x384 1 Letter: J, 1 Letter: O, 7.8ms
# Speed: 0.7ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 77
#
# 0: 384x384 1 Letter: O, 7.4ms
# Speed: 0.6ms preprocess, 7.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 78
#
# 0: 384x384 2 Letter: Os, 7.6ms
# Speed: 0.7ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 79
#
# 0: 384x384 1 Letter: O, 7.5ms
# Speed: 0.6ms preprocess, 7.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 80
#
# 0: 384x384 1 Letter: O, 7.4ms
# Speed: 0.7ms preprocess, 7.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 81
#
# 0: 384x384 1 Letter: O, 7.2ms
# Speed: 0.6ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 82
#
# 0: 384x384 1 Letter: O, 7.3ms
# Speed: 0.7ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 83
#
# 0: 384x384 1 Letter: O, 7.4ms
# Speed: 0.7ms preprocess, 7.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 84
#
# 0: 384x384 1 Letter: O, 7.5ms
# Speed: 0.6ms preprocess, 7.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 85
#
# 0: 384x384 1 Letter: O, 7.4ms
# Speed: 0.7ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 86
#
# 0: 384x384 1 Letter: O, 7.5ms
# Speed: 0.6ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 87
#
# 0: 384x384 1 Letter: O, 7.6ms
# Speed: 0.6ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 88
#
# 0: 384x384 1 Letter: O, 7.4ms
# Speed: 0.6ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 89
#
# 0: 384x384 1 Letter: O, 7.5ms
# Speed: 0.6ms preprocess, 7.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 90
#
# 0: 384x384 1 Letter: O, 7.6ms
# Speed: 0.7ms preprocess, 7.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 91
#
# 0: 384x384 1 Letter: O, 7.4ms
# Speed: 0.6ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 92
#
# 0: 384x384 1 Letter: O, 7.0ms
# Speed: 0.6ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 93
#
# 0: 384x384 1 Letter: O, 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 94
#
# 0: 384x384 1 Letter: O, 7.5ms
# Speed: 0.7ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 95
#
# 0: 384x384 1 Letter: O, 7.4ms
# Speed: 0.7ms preprocess, 7.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 96
#
# 0: 384x384 1 Letter: O, 7.7ms
# Speed: 0.6ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 97
#
# 0: 384x384 1 Letter: O, 7.4ms
# Speed: 0.7ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 98
#
# 0: 384x384 1 Letter: O, 7.5ms
# Speed: 0.7ms preprocess, 7.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 99
#
# 0: 384x384 1 Letter: O, 6.9ms
# Speed: 0.6ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 100
#
# 0: 384x384 1 Letter: O, 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 101
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 102
#
# 0: 384x384 1 Letter: O, 6.6ms
# Speed: 0.7ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 103
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 104
#
# 0: 384x384 1 Letter: O, 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 105
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 106
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 107
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.5ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 108
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.8ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 109
#
# 0: 384x384 1 Letter: O, 7.6ms
# Speed: 0.7ms preprocess, 7.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 110
#
# 0: 384x384 1 Letter: O, 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 111
#
# 0: 384x384 1 Letter: O, 7.3ms
# Speed: 0.6ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 112
#
# 0: 384x384 1 Letter: O, 7.4ms
# Speed: 0.7ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 113
#
# 0: 384x384 1 Letter: O, 7.4ms
# Speed: 0.7ms preprocess, 7.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 114
#
# 0: 384x384 1 Letter: O, 6.7ms
# Speed: 0.6ms preprocess, 6.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 115
#
# 0: 384x384 1 Letter: O, 7.3ms
# Speed: 0.7ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 116
#
# 0: 384x384 1 Letter: O, 7.3ms
# Speed: 0.7ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 117
#
# 0: 384x384 1 Letter: O, 7.2ms
# Speed: 0.7ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 118
#
# 0: 384x384 1 Letter: O, 6.4ms
# Speed: 0.7ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 119
#
# 0: 384x384 1 Letter: O, 6.4ms
# Speed: 0.7ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 120
#
# 0: 384x384 1 Letter: O, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 121
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 122
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 123
#
# 0: 384x384 1 Letter: O, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 124
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 125
#
# 0: 384x384 1 Letter: O, 6.9ms
# Speed: 0.6ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 126
#
# 0: 384x384 1 Letter: O, 7.3ms
# Speed: 0.8ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 127
#
# 0: 384x384 1 Letter: O, 7.3ms
# Speed: 0.6ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 128
#
# 0: 384x384 1 Letter: O, 7.1ms
# Speed: 0.7ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 129
#
# 0: 384x384 1 Letter: O, 7.2ms
# Speed: 0.6ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 130
#
# 0: 384x384 1 Letter: O, 7.1ms
# Speed: 0.7ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 131
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 132
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 133
#
# 0: 384x384 1 Letter: O, 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 134
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 135
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 136
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.5ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 137
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 138
#
# 0: 384x384 1 Letter: O, 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 139
#
# 0: 384x384 1 Letter: O, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 140
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 141
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 142
#
# 0: 384x384 1 Letter: O, 7.4ms
# Speed: 0.9ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 143
#
# 0: 384x384 1 Letter: O, 6.7ms
# Speed: 0.6ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 144
#
# 0: 384x384 1 Letter: O, 6.6ms
# Speed: 0.7ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 145
#
# 0: 384x384 1 Letter: O, 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 146
#
# 0: 384x384 1 Letter: O, 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 147
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 148
#
# 0: 384x384 1 Letter: O, 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 149
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 150
#
# 0: 384x384 1 Letter: O, 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 151
#
# 0: 384x384 1 Letter: O, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 152
#
# 0: 384x384 1 Letter: O, 6.9ms
# Speed: 0.6ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 153
#
# 0: 384x384 1 Letter: O, 6.7ms
# Speed: 0.6ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 154
#
# 0: 384x384 1 Letter: O, 6.7ms
# Speed: 0.6ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 155
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 156
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 157
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 158
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 159
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 160
#
# 0: 384x384 1 Letter: O, 7.4ms
# Speed: 0.8ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 161
#
# 0: 384x384 1 Letter: O, 7.2ms
# Speed: 0.8ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 162
#
# 0: 384x384 1 Letter: O, 7.4ms
# Speed: 0.6ms preprocess, 7.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 163
#
# 0: 384x384 1 Letter: O, 7.2ms
# Speed: 0.6ms preprocess, 7.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 164
#
# 0: 384x384 1 Letter: O, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 165
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 166
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 167
#
# 0: 384x384 1 Letter: O, 6.4ms
# Speed: 0.7ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 168
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 169
#
# 0: 384x384 1 Letter: O, 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 170
#
# 0: 384x384 1 Letter: O, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 171
#
# 0: 384x384 1 Letter: P, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 172
#
# 0: 384x384 1 Letter: K, 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 173
#
# 0: 384x384 1 Letter: V, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 174
#
# 0: 384x384 1 Letter: V, 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 175
#
# 0: 384x384 1 Letter: V, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 176
#
# 0: 384x384 1 Letter: V, 6.6ms
# Speed: 0.5ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 177
#
# 0: 384x384 1 Letter: V, 6.6ms
# Speed: 0.8ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 178
#
# 0: 384x384 1 Letter: V, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 179
#
# 0: 384x384 1 Letter: V, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 180
#
# 0: 384x384 1 Letter: V, 6.6ms
# Speed: 0.5ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 181
#
# 0: 384x384 1 Letter: V, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 182
#
# 0: 384x384 1 Letter: V, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 183
#
# 0: 384x384 1 Letter: V, 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 184
#
# 0: 384x384 1 Letter: V, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 185
#
# 0: 384x384 1 Letter: V, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 186
#
# 0: 384x384 1 Letter: V, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 187
#
# 0: 384x384 1 Letter: V, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 188
#
# 0: 384x384 1 Letter: V, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 189
#
# 0: 384x384 1 Letter: V, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 190
#
# 0: 384x384 1 Letter: V, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 191
#
# 0: 384x384 1 Letter: V, 6.6ms
# Speed: 0.5ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 192
#
# 0: 384x384 1 Letter: V, 6.6ms
# Speed: 0.7ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 193
#
# 0: 384x384 1 Letter: V, 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 194
#
# 0: 384x384 1 Letter: V, 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 195
#
# 0: 384x384 1 Letter: V, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 196
#
# 0: 384x384 1 Letter: V, 6.6ms
# Speed: 0.5ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 197
#
# 0: 384x384 1 Letter: V, 6.7ms
# Speed: 0.7ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 198
#
# 0: 384x384 1 Letter: V, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 199
#
# 0: 384x384 1 Letter: V, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 200
#
# 0: 384x384 1 Letter: V, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 201
#
# 0: 384x384 1 Letter: V, 6.7ms
# Speed: 0.6ms preprocess, 6.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 202
#
# 0: 384x384 1 Letter: V, 6.6ms
# Speed: 0.7ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 203
#
# 0: 384x384 1 Letter: V, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 204
#
# 0: 384x384 1 Letter: V, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 205
#
# 0: 384x384 1 Letter: V, 7.7ms
# Speed: 0.7ms preprocess, 7.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 206
#
# 0: 384x384 1 Letter: V, 4.4ms
# Speed: 0.7ms preprocess, 4.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 207
#
# 0: 384x384 1 Letter: V, 3.6ms
# Speed: 0.6ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 208
#
# 0: 384x384 1 Letter: V, 3.2ms
# Speed: 0.6ms preprocess, 3.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 209
#
# 0: 384x384 1 Letter: V, 3.3ms
# Speed: 0.6ms preprocess, 3.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 210
#
# 0: 384x384 1 Letter: V, 3.3ms
# Speed: 0.6ms preprocess, 3.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 211
#
# 0: 384x384 1 Letter: V, 3.3ms
# Speed: 0.5ms preprocess, 3.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 212
#
# 0: 384x384 1 Letter: V, 3.0ms
# Speed: 0.5ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 213
#
# 0: 384x384 1 Letter: V, 3.2ms
# Speed: 0.5ms preprocess, 3.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 214
#
# 0: 384x384 1 Letter: V, 3.3ms
# Speed: 0.5ms preprocess, 3.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 215
#
# 0: 384x384 1 Letter: V, 3.2ms
# Speed: 0.5ms preprocess, 3.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 216
#
# 0: 384x384 1 Letter: V, 3.2ms
# Speed: 0.6ms preprocess, 3.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 217
#
# 0: 384x384 1 Letter: V, 3.2ms
# Speed: 0.5ms preprocess, 3.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 218
#
# 0: 384x384 1 Letter: V, 3.3ms
# Speed: 0.5ms preprocess, 3.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 219
#
# 0: 384x384 1 Letter: V, 3.1ms
# Speed: 0.6ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 220
#
# 0: 384x384 1 Letter: V, 3.1ms
# Speed: 0.6ms preprocess, 3.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 221
#
# 0: 384x384 1 Letter: V, 3.2ms
# Speed: 0.5ms preprocess, 3.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 222
#
# 0: 384x384 1 Letter: V, 3.1ms
# Speed: 0.5ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 223
#
# 0: 384x384 1 Letter: V, 3.1ms
# Speed: 0.6ms preprocess, 3.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 224
#
# 0: 384x384 1 Letter: V, 3.3ms
# Speed: 0.5ms preprocess, 3.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 225
#
# 0: 384x384 1 Letter: V, 3.1ms
# Speed: 0.5ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 226
#
# 0: 384x384 1 Letter: V, 3.2ms
# Speed: 0.5ms preprocess, 3.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 227
#
# 0: 384x384 1 Letter: V, 3.1ms
# Speed: 0.6ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 228
#
# 0: 384x384 1 Letter: V, 3.1ms
# Speed: 0.6ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 229
#
# 0: 384x384 1 Letter: V, 3.1ms
# Speed: 0.6ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 230
#
# 0: 384x384 1 Letter: V, 3.2ms
# Speed: 0.6ms preprocess, 3.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 231
#
# 0: 384x384 1 Letter: V, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 232
#
# 0: 384x384 1 Letter: V, 4.4ms
# Speed: 0.7ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 233
#
# 0: 384x384 1 Letter: V, 4.3ms
# Speed: 0.7ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 234
#
# 0: 384x384 1 Letter: V, 4.7ms
# Speed: 0.6ms preprocess, 4.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 235
#
# 0: 384x384 1 Letter: V, 3.2ms
# Speed: 0.5ms preprocess, 3.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 236
#
# 0: 384x384 1 Letter: V, 2.8ms
# Speed: 0.6ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 237
#
# 0: 384x384 (no detections), 3.5ms
# Speed: 0.6ms preprocess, 3.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 238
#
# 0: 384x384 (no detections), 3.2ms
# Speed: 0.5ms preprocess, 3.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 239
#
# 0: 384x384 1 Letter: F, 2.8ms
# Speed: 0.5ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 240
#
# 0: 384x384 1 Letter: C, 2.9ms
# Speed: 0.5ms preprocess, 2.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 241
#
# 0: 384x384 1 Letter: O, 1 Letter: S, 2.6ms
# Speed: 0.6ms preprocess, 2.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 242
#
# 0: 384x384 1 Letter: S, 2.7ms
# Speed: 0.4ms preprocess, 2.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 243
#
# 0: 384x384 1 Letter: E, 3.4ms
# Speed: 0.5ms preprocess, 3.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 244
#
# 0: 384x384 1 Letter: S, 2.8ms
# Speed: 0.6ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 245
#
# 0: 384x384 1 Letter: S, 3.2ms
# Speed: 0.4ms preprocess, 3.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 246
#
# 0: 384x384 1 Letter: S, 2.7ms
# Speed: 0.6ms preprocess, 2.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 247
#
# 0: 384x384 1 Letter: S, 3.4ms
# Speed: 0.4ms preprocess, 3.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 248
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 2.7ms
# Speed: 0.6ms preprocess, 2.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 249
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 2.7ms
# Speed: 0.4ms preprocess, 2.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 250
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 3.2ms
# Speed: 0.5ms preprocess, 3.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 251
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 2.8ms
# Speed: 0.4ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 252
#
# 0: 384x384 1 Letter: E, 3.4ms
# Speed: 0.5ms preprocess, 3.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 253
#
# 0: 384x384 1 Letter: E, 3.5ms
# Speed: 0.4ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 254
#
# 0: 384x384 1 Letter: E, 2.6ms
# Speed: 0.6ms preprocess, 2.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 255
#
# 0: 384x384 1 Letter: E, 3.7ms
# Speed: 0.5ms preprocess, 3.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 256
#
# 0: 384x384 1 Letter: E, 3.3ms
# Speed: 0.5ms preprocess, 3.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 257
#
# 0: 384x384 1 Letter: E, 7.8ms
# Speed: 0.9ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 258
#
# 0: 384x384 1 Letter: E, 7.2ms
# Speed: 0.6ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 259
#
# 0: 384x384 1 Letter: E, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 260
#
# 0: 384x384 1 Letter: E, 6.3ms
# Speed: 0.6ms preprocess, 6.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 261
#
# 0: 384x384 1 Letter: E, 6.4ms
# Speed: 0.5ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 262
#
# 0: 384x384 1 Letter: S, 6.4ms
# Speed: 0.7ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 263
#
# 0: 384x384 1 Letter: S, 6.3ms
# Speed: 0.6ms preprocess, 6.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 264
#
# 0: 384x384 1 Letter: S, 6.4ms
# Speed: 0.5ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 265
#
# 0: 384x384 1 Letter: S, 6.4ms
# Speed: 0.7ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 266
#
# 0: 384x384 1 Letter: S, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 267
#
# 0: 384x384 1 Letter: S, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 268
#
# 0: 384x384 1 Letter: S, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 269
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 6.3ms
# Speed: 0.5ms preprocess, 6.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 270
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 271
#
# 0: 384x384 1 Letter: S, 6.2ms
# Speed: 0.7ms preprocess, 6.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 272
#
# 0: 384x384 1 Letter: S, 6.3ms
# Speed: 0.5ms preprocess, 6.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 273
#
# 0: 384x384 1 Letter: E, 6.3ms
# Speed: 0.8ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 274
#
# 0: 384x384 1 Letter: E, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 275
#
# 0: 384x384 1 Letter: E, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 276
#
# 0: 384x384 1 Letter: E, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 277
#
# 0: 384x384 1 Letter: E, 6.3ms
# Speed: 0.5ms preprocess, 6.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 278
#
# 0: 384x384 1 Letter: E, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 279
#
# 0: 384x384 1 Letter: E, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 280
#
# 0: 384x384 1 Letter: S, 6.4ms
# Speed: 0.5ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 281
#
# 0: 384x384 1 Letter: S, 6.3ms
# Speed: 0.7ms preprocess, 6.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 282
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 6.3ms
# Speed: 0.5ms preprocess, 6.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 283
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 284
#
# 0: 384x384 1 Letter: S, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 285
#
# 0: 384x384 1 Letter: S, 6.3ms
# Speed: 0.6ms preprocess, 6.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 286
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 287
#
# 0: 384x384 1 Letter: S, 6.3ms
# Speed: 0.6ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 288
#
# 0: 384x384 1 Letter: S, 6.3ms
# Speed: 0.5ms preprocess, 6.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 289
#
# 0: 384x384 1 Letter: S, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 290
#
# 0: 384x384 1 Letter: S, 6.3ms
# Speed: 0.7ms preprocess, 6.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 291
#
# 0: 384x384 1 Letter: S, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 292
#
# 0: 384x384 1 Letter: S, 6.3ms
# Speed: 0.8ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 293
#
# 0: 384x384 1 Letter: S, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 294
#
# 0: 384x384 1 Letter: S, 6.4ms
# Speed: 0.6ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 295
#
# 0: 384x384 1 Letter: S, 3.4ms
# Speed: 0.8ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 296
#
# 0: 384x384 1 Letter: S, 3.4ms
# Speed: 0.5ms preprocess, 3.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 297
#
# 0: 384x384 1 Letter: S, 3.2ms
# Speed: 0.5ms preprocess, 3.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 298
#
# 0: 384x384 1 Letter: S, 3.0ms
# Speed: 0.5ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 299
#
# 0: 384x384 1 Letter: S, 2.7ms
# Speed: 0.5ms preprocess, 2.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 300
#
# 0: 384x384 1 Letter: S, 2.8ms
# Speed: 0.4ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 301
#
# 0: 384x384 1 Letter: S, 2.7ms
# Speed: 0.4ms preprocess, 2.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 302
#
# 0: 384x384 1 Letter: S, 2.9ms
# Speed: 0.4ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 303
#
# 0: 384x384 1 Letter: S, 3.0ms
# Speed: 0.5ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 304
#
# 0: 384x384 1 Letter: S, 3.0ms
# Speed: 0.5ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 305
#
# 0: 384x384 1 Letter: S, 2.9ms
# Speed: 0.5ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 306
#
# 0: 384x384 1 Letter: S, 2.9ms
# Speed: 0.5ms preprocess, 2.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 307
#
# 0: 384x384 1 Letter: S, 3.1ms
# Speed: 0.5ms preprocess, 3.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 308
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 2.9ms
# Speed: 0.5ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 309
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 2.9ms
# Speed: 0.4ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 310
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 2.8ms
# Speed: 0.5ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 311
#
# 0: 384x384 1 Letter: E, 5.5ms
# Speed: 0.7ms preprocess, 5.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 312
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 5.3ms
# Speed: 0.8ms preprocess, 5.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 313
#
# 0: 384x384 1 Letter: E, 3.4ms
# Speed: 0.5ms preprocess, 3.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 314
#
# 0: 384x384 1 Letter: E, 4.7ms
# Speed: 0.6ms preprocess, 4.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 315
#
# 0: 384x384 1 Letter: E, 2.9ms
# Speed: 0.5ms preprocess, 2.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 316
#
# 0: 384x384 1 Letter: E, 2.8ms
# Speed: 0.5ms preprocess, 2.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 317
#
# 0: 384x384 1 Letter: E, 2.7ms
# Speed: 0.4ms preprocess, 2.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 318
#
# 0: 384x384 1 Letter: E, 3.0ms
# Speed: 0.5ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 319
#
# 0: 384x384 1 Letter: E, 3.0ms
# Speed: 0.5ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 320
#
# 0: 384x384 1 Letter: E, 2.9ms
# Speed: 0.4ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 321
#
# 0: 384x384 1 Letter: E, 3.0ms
# Speed: 0.5ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 322
#
# 0: 384x384 1 Letter: E, 3.0ms
# Speed: 0.4ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 323
# End of video or failed to read frame.
# Processed video saved to: output_video.mp4

# %%
yolo11l_model = YOLO(f'./{metrics_files["YOLO-l"]}/weights/best.pt')

# %%
generate_inference_video(yolo11l_model, 'test_inference.mp4',
                         'output_video_l.mp4')
# Out:
# 0: 384x384 1 Letter: L, 11.7ms
# Speed: 0.5ms preprocess, 11.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 1
#
# 0: 384x384 1 Letter: L, 12.3ms
# Speed: 0.6ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 2
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.5ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 3
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 4
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 5
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 6
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 7
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 8
#
# 0: 384x384 1 Letter: L, 12.3ms
# Speed: 0.7ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 9
#
# 0: 384x384 1 Letter: L, 12.2ms
# Speed: 0.5ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 10
#
# 0: 384x384 1 Letter: L, 12.3ms
# Speed: 0.6ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 11
#
# 0: 384x384 1 Letter: L, 12.2ms
# Speed: 0.7ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 12
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 13
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 14
#
# 0: 384x384 1 Letter: L, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 15
#
# 0: 384x384 1 Letter: L, 12.2ms
# Speed: 0.7ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 16
#
# 0: 384x384 1 Letter: L, 11.9ms
# Speed: 0.7ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 17
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.8ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 18
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.8ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 19
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 20
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 21
#
# 0: 384x384 1 Letter: L, 11.9ms
# Speed: 0.6ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 22
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 23
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 24
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 25
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 26
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 27
#
# 0: 384x384 1 Letter: L, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 28
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 29
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 30
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 31
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 32
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 33
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.8ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 34
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 35
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.8ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 36
#
# 0: 384x384 1 Letter: L, 11.9ms
# Speed: 0.5ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 37
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 38
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 39
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 40
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 41
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.5ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 42
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 43
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 44
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 45
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 46
#
# 0: 384x384 1 Letter: L, 12.2ms
# Speed: 0.7ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 47
#
# 0: 384x384 1 Letter: L, 12.2ms
# Speed: 0.7ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 48
#
# 0: 384x384 1 Letter: L, 12.2ms
# Speed: 0.7ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 49
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 50
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 51
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 52
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 53
#
# 0: 384x384 1 Letter: L, 11.9ms
# Speed: 0.6ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 54
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 55
#
# 0: 384x384 1 Letter: L, 11.9ms
# Speed: 0.6ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 56
#
# 0: 384x384 1 Letter: L, 11.9ms
# Speed: 0.7ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 57
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 58
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 59
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 60
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 61
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.5ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 62
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 63
#
# 0: 384x384 1 Letter: L, 11.9ms
# Speed: 0.7ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 64
#
# 0: 384x384 1 Letter: L, 1 Letter: Y, 11.9ms
# Speed: 0.6ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 65
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 66
#
# 0: 384x384 1 Letter: L, 12.0ms
# Speed: 0.5ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 67
#
# 0: 384x384 1 Letter: L, 11.9ms
# Speed: 0.6ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 68
#
# 0: 384x384 1 Letter: L, 11.9ms
# Speed: 0.7ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 69
#
# 0: 384x384 1 Letter: I, 1 Letter: L, 12.2ms
# Speed: 0.7ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 70
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 71
#
# 0: 384x384 1 Letter: L, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 72
#
# 0: 384x384 1 Letter: L, 1 Letter: Y, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 73
#
# 0: 384x384 1 Letter: I, 1 Letter: X, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 74
#
# 0: 384x384 1 Letter: O, 12.3ms
# Speed: 0.6ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 75
#
# 0: 384x384 1 Letter: O, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 76
#
# 0: 384x384 1 Letter: O, 12.6ms
# Speed: 0.8ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 77
#
# 0: 384x384 1 Letter: O, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 78
#
# 0: 384x384 1 Letter: O, 12.2ms
# Speed: 0.5ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 79
#
# 0: 384x384 1 Letter: O, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 80
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 81
#
# 0: 384x384 1 Letter: O, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 82
#
# 0: 384x384 1 Letter: O, 12.3ms
# Speed: 0.5ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 83
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 84
#
# 0: 384x384 1 Letter: O, 12.2ms
# Speed: 0.7ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 85
#
# 0: 384x384 1 Letter: O, 12.3ms
# Speed: 0.6ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 86
#
# 0: 384x384 1 Letter: O, 12.5ms
# Speed: 0.6ms preprocess, 12.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 87
#
# 0: 384x384 1 Letter: O, 12.3ms
# Speed: 0.7ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 88
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 89
#
# 0: 384x384 1 Letter: O, 11.9ms
# Speed: 0.6ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 90
#
# 0: 384x384 1 Letter: O, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 91
#
# 0: 384x384 1 Letter: O, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 92
#
# 0: 384x384 1 Letter: O, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 93
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 94
#
# 0: 384x384 1 Letter: O, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 95
#
# 0: 384x384 1 Letter: O, 12.3ms
# Speed: 0.6ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 96
#
# 0: 384x384 1 Letter: O, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 97
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 98
#
# 0: 384x384 1 Letter: O, 12.3ms
# Speed: 0.6ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 99
#
# 0: 384x384 1 Letter: O, 12.3ms
# Speed: 0.6ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 100
#
# 0: 384x384 1 Letter: O, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 101
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 102
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 103
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 104
#
# 0: 384x384 1 Letter: O, 12.3ms
# Speed: 0.6ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 105
#
# 0: 384x384 1 Letter: O, 12.3ms
# Speed: 0.6ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 106
#
# 0: 384x384 1 Letter: O, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 107
#
# 0: 384x384 1 Letter: O, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 108
#
# 0: 384x384 1 Letter: O, 13.4ms
# Speed: 0.7ms preprocess, 13.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 109
#
# 0: 384x384 1 Letter: O, 12.3ms
# Speed: 0.6ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 110
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 111
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 112
#
# 0: 384x384 1 Letter: O, 11.8ms
# Speed: 0.6ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 113
#
# 0: 384x384 1 Letter: O, 11.9ms
# Speed: 0.6ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 114
#
# 0: 384x384 1 Letter: O, 11.9ms
# Speed: 0.5ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 115
#
# 0: 384x384 1 Letter: O, 11.8ms
# Speed: 0.5ms preprocess, 11.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 116
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.5ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 117
#
# 0: 384x384 1 Letter: O, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 118
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 119
#
# 0: 384x384 1 Letter: O, 11.9ms
# Speed: 0.6ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 120
#
# 0: 384x384 1 Letter: O, 11.9ms
# Speed: 0.6ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 121
#
# 0: 384x384 1 Letter: O, 11.9ms
# Speed: 0.6ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 122
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.5ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 123
#
# 0: 384x384 1 Letter: O, 12.1ms
# Speed: 0.5ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 124
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 125
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 126
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 127
#
# 0: 384x384 1 Letter: O, 13.4ms
# Speed: 0.6ms preprocess, 13.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 128
#
# 0: 384x384 1 Letter: O, 13.3ms
# Speed: 0.7ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 129
#
# 0: 384x384 1 Letter: O, 13.0ms
# Speed: 0.7ms preprocess, 13.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 130
#
# 0: 384x384 1 Letter: O, 11.9ms
# Speed: 0.7ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 131
#
# 0: 384x384 1 Letter: O, 11.9ms
# Speed: 0.6ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 132
#
# 0: 384x384 1 Letter: O, 11.8ms
# Speed: 0.7ms preprocess, 11.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 133
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.5ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 134
#
# 0: 384x384 1 Letter: O, 11.9ms
# Speed: 0.6ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 135
#
# 0: 384x384 1 Letter: O, 11.8ms
# Speed: 0.5ms preprocess, 11.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 136
#
# 0: 384x384 1 Letter: O, 11.8ms
# Speed: 0.6ms preprocess, 11.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 137
#
# 0: 384x384 1 Letter: O, 11.9ms
# Speed: 0.6ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 138
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 139
#
# 0: 384x384 1 Letter: O, 11.9ms
# Speed: 0.6ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 140
#
# 0: 384x384 1 Letter: O, 11.9ms
# Speed: 0.8ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 141
#
# 0: 384x384 1 Letter: O, 11.9ms
# Speed: 0.7ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 142
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 143
#
# 0: 384x384 1 Letter: O, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 144
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.5ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 145
#
# 0: 384x384 1 Letter: O, 12.1ms
# Speed: 0.5ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 146
#
# 0: 384x384 1 Letter: O, 12.2ms
# Speed: 0.5ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 147
#
# 0: 384x384 1 Letter: O, 12.2ms
# Speed: 0.7ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 148
#
# 0: 384x384 1 Letter: O, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 149
#
# 0: 384x384 1 Letter: O, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 150
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 151
#
# 0: 384x384 1 Letter: O, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 152
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 153
#
# 0: 384x384 1 Letter: O, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 154
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 155
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 156
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 157
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 158
#
# 0: 384x384 1 Letter: O, 11.9ms
# Speed: 0.5ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 159
#
# 0: 384x384 1 Letter: O, 11.9ms
# Speed: 0.5ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 160
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 161
#
# 0: 384x384 1 Letter: O, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 162
#
# 0: 384x384 1 Letter: O, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 163
#
# 0: 384x384 1 Letter: O, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 164
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 165
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 166
#
# 0: 384x384 1 Letter: O, 11.9ms
# Speed: 0.6ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 167
#
# 0: 384x384 1 Letter: O, 12.9ms
# Speed: 0.7ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 168
#
# 0: 384x384 1 Letter: O, 1 Letter: P, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 169
#
# 0: 384x384 1 Letter: P, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 170
#
# 0: 384x384 1 Letter: P, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 171
#
# 0: 384x384 1 Letter: C, 1 Letter: P, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 172
#
# 0: 384x384 1 Letter: P, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 173
#
# 0: 384x384 (no detections), 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 174
#
# 0: 384x384 1 Letter: V, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 175
#
# 0: 384x384 1 Letter: V, 12.3ms
# Speed: 0.5ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 176
#
# 0: 384x384 1 Letter: V, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 177
#
# 0: 384x384 1 Letter: V, 12.3ms
# Speed: 0.7ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 178
#
# 0: 384x384 1 Letter: V, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 179
#
# 0: 384x384 1 Letter: V, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 180
#
# 0: 384x384 1 Letter: V, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 181
#
# 0: 384x384 1 Letter: V, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 182
#
# 0: 384x384 1 Letter: V, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 183
#
# 0: 384x384 1 Letter: V, 14.0ms
# Speed: 0.6ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 184
#
# 0: 384x384 1 Letter: V, 13.0ms
# Speed: 0.6ms preprocess, 13.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 185
#
# 0: 384x384 1 Letter: V, 12.7ms
# Speed: 0.6ms preprocess, 12.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 186
#
# 0: 384x384 1 Letter: V, 12.4ms
# Speed: 0.6ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 187
#
# 0: 384x384 1 Letter: V, 12.6ms
# Speed: 0.5ms preprocess, 12.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 188
#
# 0: 384x384 1 Letter: V, 12.4ms
# Speed: 0.5ms preprocess, 12.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 189
#
# 0: 384x384 1 Letter: V, 12.3ms
# Speed: 0.7ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 190
#
# 0: 384x384 1 Letter: V, 12.4ms
# Speed: 0.7ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 191
#
# 0: 384x384 1 Letter: V, 12.3ms
# Speed: 0.6ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 192
#
# 0: 384x384 1 Letter: V, 12.4ms
# Speed: 0.6ms preprocess, 12.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 193
#
# 0: 384x384 1 Letter: V, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 194
#
# 0: 384x384 1 Letter: V, 12.3ms
# Speed: 0.6ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 195
#
# 0: 384x384 1 Letter: V, 12.4ms
# Speed: 0.6ms preprocess, 12.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 196
#
# 0: 384x384 1 Letter: V, 12.2ms
# Speed: 0.5ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 197
#
# 0: 384x384 1 Letter: V, 12.3ms
# Speed: 0.5ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 198
#
# 0: 384x384 1 Letter: V, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 199
#
# 0: 384x384 1 Letter: V, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 200
#
# 0: 384x384 1 Letter: V, 12.4ms
# Speed: 0.6ms preprocess, 12.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 201
#
# 0: 384x384 1 Letter: V, 12.2ms
# Speed: 0.5ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 202
#
# 0: 384x384 1 Letter: V, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 203
#
# 0: 384x384 1 Letter: V, 12.2ms
# Speed: 0.7ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 204
#
# 0: 384x384 1 Letter: V, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 205
#
# 0: 384x384 1 Letter: V, 12.3ms
# Speed: 0.7ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 206
#
# 0: 384x384 1 Letter: V, 12.3ms
# Speed: 0.5ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 207
#
# 0: 384x384 1 Letter: V, 12.2ms
# Speed: 0.5ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 208
#
# 0: 384x384 1 Letter: V, 12.0ms
# Speed: 0.5ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 209
#
# 0: 384x384 1 Letter: V, 12.0ms
# Speed: 0.5ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 210
#
# 0: 384x384 1 Letter: V, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 211
#
# 0: 384x384 1 Letter: V, 11.9ms
# Speed: 0.7ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 212
#
# 0: 384x384 1 Letter: V, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 213
#
# 0: 384x384 1 Letter: V, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 214
#
# 0: 384x384 1 Letter: V, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 215
#
# 0: 384x384 1 Letter: V, 12.0ms
# Speed: 0.5ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 216
#
# 0: 384x384 1 Letter: V, 7.1ms
# Speed: 0.5ms preprocess, 7.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 217
#
# 0: 384x384 1 Letter: V, 13.9ms
# Speed: 0.7ms preprocess, 13.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 218
#
# 0: 384x384 1 Letter: V, 12.4ms
# Speed: 0.7ms preprocess, 12.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 219
#
# 0: 384x384 1 Letter: V, 12.2ms
# Speed: 0.7ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 220
#
# 0: 384x384 1 Letter: V, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 221
#
# 0: 384x384 1 Letter: V, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 222
#
# 0: 384x384 1 Letter: V, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 223
#
# 0: 384x384 1 Letter: V, 12.2ms
# Speed: 0.5ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 224
#
# 0: 384x384 1 Letter: V, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 225
#
# 0: 384x384 1 Letter: V, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 226
#
# 0: 384x384 1 Letter: V, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 227
#
# 0: 384x384 1 Letter: V, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 228
#
# 0: 384x384 1 Letter: V, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 229
#
# 0: 384x384 1 Letter: V, 12.2ms
# Speed: 0.5ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 230
#
# 0: 384x384 1 Letter: V, 13.4ms
# Speed: 0.5ms preprocess, 13.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 231
#
# 0: 384x384 1 Letter: V, 12.5ms
# Speed: 0.7ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 232
#
# 0: 384x384 1 Letter: V, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 233
#
# 0: 384x384 1 Letter: V, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 234
#
# 0: 384x384 1 Letter: V, 12.0ms
# Speed: 0.5ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 235
#
# 0: 384x384 1 Letter: V, 11.9ms
# Speed: 0.5ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 236
#
# 0: 384x384 1 Letter: V, 11.9ms
# Speed: 0.7ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 237
#
# 0: 384x384 1 Letter: V, 11.9ms
# Speed: 0.7ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 238
#
# 0: 384x384 1 Letter: F, 1 Letter: K, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 239
#
# 0: 384x384 1 Letter: F, 1 Letter: O, 12.0ms
# Speed: 0.5ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 240
#
# 0: 384x384 1 Letter: O, 11.9ms
# Speed: 0.6ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 241
#
# 0: 384x384 1 Letter: O, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 242
#
# 0: 384x384 1 Letter: O, 1 Letter: S, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 243
#
# 0: 384x384 1 Letter: O, 1 Letter: S, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 244
#
# 0: 384x384 1 Letter: S, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 245
#
# 0: 384x384 1 Letter: S, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 246
#
# 0: 384x384 1 Letter: S, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 247
#
# 0: 384x384 1 Letter: S, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 248
#
# 0: 384x384 1 Letter: S, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 249
#
# 0: 384x384 1 Letter: S, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 250
#
# 0: 384x384 1 Letter: S, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 251
#
# 0: 384x384 1 Letter: S, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 252
#
# 0: 384x384 1 Letter: S, 12.4ms
# Speed: 0.6ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 253
#
# 0: 384x384 1 Letter: S, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 254
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 255
#
# 0: 384x384 1 Letter: E, 12.2ms
# Speed: 0.7ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 256
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 257
#
# 0: 384x384 1 Letter: E, 13.1ms
# Speed: 0.8ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 258
#
# 0: 384x384 1 Letter: E, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 259
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 260
#
# 0: 384x384 1 Letter: E, 12.3ms
# Speed: 0.7ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 261
#
# 0: 384x384 1 Letter: E, 12.2ms
# Speed: 0.7ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 262
#
# 0: 384x384 1 Letter: E, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 263
#
# 0: 384x384 1 Letter: E, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 264
#
# 0: 384x384 1 Letter: E, 12.2ms
# Speed: 0.7ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 265
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 266
#
# 0: 384x384 1 Letter: E, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 267
#
# 0: 384x384 1 Letter: E, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 268
#
# 0: 384x384 1 Letter: E, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 269
#
# 0: 384x384 1 Letter: E, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 270
#
# 0: 384x384 1 Letter: E, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 271
#
# 0: 384x384 1 Letter: E, 12.2ms
# Speed: 0.7ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 272
#
# 0: 384x384 1 Letter: E, 12.2ms
# Speed: 0.7ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 273
#
# 0: 384x384 1 Letter: E, 12.3ms
# Speed: 0.6ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 274
#
# 0: 384x384 1 Letter: E, 14.0ms
# Speed: 0.7ms preprocess, 14.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 275
#
# 0: 384x384 1 Letter: E, 12.3ms
# Speed: 0.7ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 276
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 12.1ms
# Speed: 0.5ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 277
#
# 0: 384x384 1 Letter: E, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 278
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 279
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 280
#
# 0: 384x384 1 Letter: E, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 281
#
# 0: 384x384 1 Letter: E, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 282
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 283
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 284
#
# 0: 384x384 1 Letter: E, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 285
#
# 0: 384x384 1 Letter: E, 11.9ms
# Speed: 0.7ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 286
#
# 0: 384x384 1 Letter: E, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 287
#
# 0: 384x384 1 Letter: E, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 288
#
# 0: 384x384 1 Letter: E, 12.2ms
# Speed: 0.7ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 289
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 12.2ms
# Speed: 0.5ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 290
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 12.3ms
# Speed: 0.6ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 291
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 292
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 293
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 294
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 12.0ms
# Speed: 0.5ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 295
#
# 0: 384x384 1 Letter: E, 12.0ms
# Speed: 0.5ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 296
#
# 0: 384x384 1 Letter: E, 12.4ms
# Speed: 0.5ms preprocess, 12.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 297
#
# 0: 384x384 1 Letter: E, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 298
#
# 0: 384x384 1 Letter: E, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 299
#
# 0: 384x384 1 Letter: E, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 300
#
# 0: 384x384 1 Letter: E, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 301
#
# 0: 384x384 1 Letter: E, 12.2ms
# Speed: 0.5ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 302
#
# 0: 384x384 1 Letter: E, 12.3ms
# Speed: 0.6ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 303
#
# 0: 384x384 1 Letter: E, 12.2ms
# Speed: 0.7ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 304
#
# 0: 384x384 1 Letter: E, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 305
#
# 0: 384x384 1 Letter: E, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 306
#
# 0: 384x384 1 Letter: E, 12.2ms
# Speed: 0.5ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 307
#
# 0: 384x384 1 Letter: E, 12.2ms
# Speed: 0.5ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 308
#
# 0: 384x384 1 Letter: E, 12.2ms
# Speed: 0.5ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 309
#
# 0: 384x384 1 Letter: E, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 310
#
# 0: 384x384 1 Letter: E, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 311
#
# 0: 384x384 1 Letter: E, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 312
#
# 0: 384x384 1 Letter: E, 13.6ms
# Speed: 0.6ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 313
#
# 0: 384x384 1 Letter: E, 12.4ms
# Speed: 0.7ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 314
#
# 0: 384x384 1 Letter: E, 12.2ms
# Speed: 0.7ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 315
#
# 0: 384x384 1 Letter: E, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 316
#
# 0: 384x384 1 Letter: E, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 317
#
# 0: 384x384 1 Letter: E, 12.0ms
# Speed: 0.5ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 318
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 319
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 320
#
# 0: 384x384 1 Letter: E, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 321
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 12.1ms
# Speed: 0.5ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 322
#
# 0: 384x384 1 Letter: E, 1 Letter: S, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
# Processed frame 323
# End of video or failed to read frame.
# Processed video saved to: output_video_l.mp4
